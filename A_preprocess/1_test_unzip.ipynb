# %%
import os, sys
sys.path.append(os.path.abspath('..'))
from utils.preprocess_data import unzip_csv_gz

# %%
os.listdir("data_jo_raw")
# Out:
# ['listings_london2403.csv.gz',
#  'listings_london2406.csv.gz',
#  'listings_london2409.csv.gz',
#  'listings_london2412.csv.gz']

# %%
unzip_csv_gz('data_jo_raw', 'data_jo')
# Out:
# 0 ✔ listings_london2403.csv converted and saved in data_jo!
#
# 1 listings_london2406.csv already exists in data_jo!
#
# 2 listings_london2409.csv already exists in data_jo!
#
# 3 listings_london2412.csv already exists in data_jo!
