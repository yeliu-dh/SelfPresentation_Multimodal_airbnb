# %%
import os, sys, importlib
sys.path.append(os.path.abspath(".."))
import json
import pandas as pd

# %% [markdown]
# ## input :

# %%
# DATA_FOLDER="../data_processed"
# dict_input={}
# for folder in os.listdir(DATA_FOLDER):
#     files=os.listdir(os.path.join(DATA_FOLDER, folder))
#     for f in files:
#         if f.startswith('listings'):
#             path_listings=os.path.join(DATA_FOLDER, folder, f)
#             if "processed" in f:
#                 path_listings_zsc=os.path.join(DATA_FOLDER, folder, f.replace("processed","zsc"))
#             else : 
#                 path_listings_zsc=os.path.join(DATA_FOLDER, folder, f"listings_zsc_{folder}.csv")

#     path_results=os.path.join(DATA_FOLDER, folder, f"resultsZSC_{folder}.csv")
    
    
#     dict_input[folder]={"listings":path_listings,
#                        "results":path_results,
#                        "listings_zsc":path_listings_zsc}

# for k,v in dict_input.items():
#     print(k)
#     path_listings=v['listings']
#     path_results=v['results']
#     path_listings_zsc=v['listings_zsc']

#     print(path_listings)
#     print(path_results)
#     print(path_listings_zsc,"\n")
# Out:
# london_2306
# ../data_processed\london_2306\listings_processed_london_2306_42356.csv
# ../data_processed\london_2306\resultsZSC_london_2306.csv
# ../data_processed\london_2306\listings_zsc_london_2306_42356.csv
#
# london_2406
# ../data_processed\london_2406\listings_processed_london_2406_49856.csv
# ../data_processed\london_2406\resultsZSC_london_2406.csv
# ../data_processed\london_2406\listings_zsc_london_2406_49856.csv
#
# paris_2306
# ../data_processed\paris_2306\listings_processed_paris_2306_32901.csv
# ../data_processed\paris_2306\resultsZSC_paris_2306.csv
# ../data_processed\paris_2306\listings_zsc_paris_2306_32901.csv
#
# paris_2406
# ../data_processed\paris_2406\listings_processed_paris_2406_62738.csv
# ../data_processed\paris_2406\resultsZSC_paris_2406.csv
# ../data_processed\paris_2406\listings_zsc_paris_2406_62738.csv

# %% [markdown]
# ## zsc

# %%
df_input=pd.read_csv("../data_processed\paris2406\listings_processed_paris2406_62738.csv")

# %%
from utils import zsc
importlib.reload(zsc)
from utils.zsc import run_zsc

df_zsc=run_zsc(
    df_input,
    model_name="MoritzLaurer/bge-m3-zeroshot-v2.0",#"MoritzLaurer/bge-m3-zeroshot-v2.0", #"tasksource/ModernBERT-large-nli",#par défaut
    by_lang=True,
    path_results="../data_processed\paris2406/resultsZSC_listings_paris_2406.csv", 
    save_interval=5, 
    )
# Out:
# [info] df: 62738; df_unique : 16206
#
# [info] 18449 rows already zsced; 0 rows to zsc!
#
# loading model...
# Device set to use cpu
# zsc by lang !
# ZSC text...: 0it [00:00, ?it/s]
# [DONE] ZSC sur 62738 textes avec 22 EN labels/22 FR labels
# par MoritzLaurer/bge-m3-zeroshot-v2.0 prend 0.00 hours ( 0.00 sec)!
#
# df_zsc: (62738, 107);
