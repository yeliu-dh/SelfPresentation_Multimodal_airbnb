# %%
import os, sys, importlib
sys.path.append(os.path.abspath(".."))
import json
import pandas as pd

# %%
results_zsc=pd.read_csv("../data_processed\paris2406\listings_paris2406_zsc18449.csv")
print(results_zsc.shape)
display(results_zsc.head())
# Out:
# (18449, 24)
#       id                                               text  welcoming  \
# 0  80301   Doctorat Sorbonne 1,Litterature sciences huma...   0.924891
# 1   5396  We have spent a lot of time traveling for work...   0.986507
# 2   7397  I am a writer,54, author of novels, books of l...   0.073563
# 3  80327  - - - - Love to travel , meet new people ... -...   0.554459
# 4   7964  Hello ! \r\nOur apartment is great and I am su...   0.996870
#
#    sociable  open to different cultures  willing to help  \
# 0  0.921922                    0.824956         0.792785
# 1  0.982922                    0.326647         0.912006
# 2  0.013506                    0.189521         0.022032
# 3  0.970909                    0.742468         0.018671
# 4  0.951504                    0.394463         0.983801
#
#    interpersonal interaction  international view  cultural exchange  \
# 0                   0.778565            0.772702           0.683921
# 1                   0.953708            0.957398           0.589421
# 2                   0.002621            0.025468           0.012218
# 3                   0.806396            0.839668           0.285073
# 4                   0.996427            0.302855           0.040503
#
#    attentive to needs  ...  life experiences  meet new people  \
# 0            0.678114  ...          0.380457         0.056029
# 1            0.995226  ...          0.876793         0.111000
# 2            0.103295  ...          0.007681         0.000565
# 3            0.035847  ...          0.535645         0.978834
# 4            0.815893  ...          0.086942         0.826782
#
#    divers interests   hobbies  fan of Airbnb  personal life  Airbnb community  \
# 0          0.039342  0.021065       0.020158       0.006451          0.004774
# 1          0.508575  0.008284       0.285223       0.010673          0.747109
# 2          0.862410  0.062847       0.000320       0.015845          0.000885
# 3          0.927297  0.988613       0.007621       0.863449          0.024031
# 4          0.174410  0.000454       0.291485       0.250913          0.898098
#
#    travel with Airbnb  love Airbnb  enjoy life
# 0            0.003969     0.002003    0.000725
# 1            0.311270     0.138229    0.722967
# 2            0.001216     0.000308    0.001585
# 3            0.022716     0.009003    0.943660
# 4            0.690559     0.050377    0.178526
#
# [5 rows x 24 columns]
