# %%
import os, sys
# sys.path.append(os.path.abspath('..'))
# from utils.split_listings import unzip_csv_gz

def unzip_csv_gz(folder='raw_data', output_folder='data'):
    os.makedirs(output_folder, exist_ok=True)

    for i, filename in enumerate(os.listdir(folder)):
        file_path = os.path.join(folder, filename)

        # 只处理 .gz 文件
        if not filename.endswith('.gz'):
            print(f"{i} {filename} is not a gzip file, skipped.\n")
            continue

        filename_clean = os.path.splitext(filename)[0]  # 去掉 .gz
        file_outpath = os.path.join(output_folder, filename_clean)

        # 如果输出文件已存在，跳过
        if os.path.exists(file_outpath):
            print(f"{i} {filename_clean} already exists in {output_folder}!\n")
            continue

        try:
            df = pd.read_csv(file_path, compression='gzip', encoding='utf-8')
            df.to_csv(file_outpath, index=False)
            print(f"{i} ✔ {filename_clean} converted and saved in {output_folder}!\n")
        
        except Exception as e:
            print(f"{i} ❌ Error converting {filename}: {e}\n")

# %%
os.listdir("../data_raw_gz")
# Out:
# ['listings_london2306.csv.gz',
#  'listings_london2309.csv.gz',
#  'listings_london2312.csv.gz',
#  'listings_london2403.csv.gz',
#  'listings_london2406.csv.gz',
#  'listings_london2409.csv.gz',
#  'listings_london2412.csv.gz',
#  'listings_london_2506.csv.gz',
#  'listings_paris2303.csv.gz',
#  'listings_paris2306.csv.gz',
#  'listings_paris2309.csv.gz',
#  'listings_paris_2506.csv.gz']

# %%
unzip_csv_gz("../data_raw_gz", '../data_raw')
# Out:
# 0 ✔ listings_london2306.csv converted and saved in ../data_raw!
# d:\Edu\SelfPresentation_Multimodal_airbnb\utils\split_listings.py:29: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, compression='gzip', encoding='utf-8')
# 1 ✔ listings_london2309.csv converted and saved in ../data_raw!
#
# 2 ✔ listings_london2312.csv converted and saved in ../data_raw!
#
# 3 ✔ listings_london2403.csv converted and saved in ../data_raw!
#
# 4 ✔ listings_london2406.csv converted and saved in ../data_raw!
#
# 5 ✔ listings_london2409.csv converted and saved in ../data_raw!
#
# 6 ✔ listings_london2412.csv converted and saved in ../data_raw!
#
# 7 ✔ listings_london_2506.csv converted and saved in ../data_raw!
#
# 8 ✔ listings_paris2303.csv converted and saved in ../data_raw!
#
# 9 ✔ listings_paris2306.csv converted and saved in ../data_raw!
#
# 10 ✔ listings_paris2309.csv converted and saved in ../data_raw!
#
# 11 ✔ listings_paris_2506.csv converted and saved in ../data_raw!
