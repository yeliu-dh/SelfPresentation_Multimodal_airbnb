# %%
import os, sys, imaplib, pathlib
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.99-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.12/dist-packages (from deepface) (2.32.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from deepface) (2.0.2)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.12/dist-packages (from deepface) (2.2.2)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from deepface) (5.2.1)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from deepface) (4.67.3)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from deepface) (11.3.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.12/dist-packages (from deepface) (4.13.0.92)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from deepface) (2.19.0)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from deepface) (3.10.0)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from deepface) (3.1.3)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.14 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-25.1.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightphe>=0.0.15 (from deepface)
#   Downloading lightphe-0.0.20-py3-none-any.whl.metadata (13 kB)
# Collecting lightdsa>=0.0.3 (from deepface)
#   Downloading lightdsa-0.0.3-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from deepface) (1.2.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire>=0.4.0->deepface) (3.3.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask>=1.1.2->deepface) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=3.10.1->deepface) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=3.10.1->deepface) (3.24.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gunicorn>=20.1.0->deepface) (26.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=2.2.0->deepface) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=2.2.0->deepface) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=2.2.0->deepface) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=2.2.0->deepface) (0.19.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=2.2.0->deepface) (0.5.4)
# Collecting lightecc (from lightdsa>=0.0.3->deepface)
#   Downloading lightecc-0.0.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from lightdsa>=0.0.3->deepface) (1.14.0)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from mtcnn>=0.1.0->deepface) (1.5.3)
# Collecting lz4>=4.3.3 (from mtcnn>=0.1.0->deepface)
#   Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.4->deepface) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->deepface) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->deepface) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->deepface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->deepface) (2026.2.25)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (5.29.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.9.0->deepface) (2.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.46.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->lightdsa>=0.0.3->deepface) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=2.2.0->deepface) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=2.2.0->deepface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Downloading deepface-0.0.99-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 12.0 MB/s eta 0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 14.6 MB/s eta 0:00:00
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading gunicorn-25.1.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.1/197.1 kB 23.2 MB/s eta 0:00:00
# Downloading lightdsa-0.0.3-py3-none-any.whl (17 kB)
# Downloading lightphe-0.0.20-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 7.1 MB/s eta 0:00:00
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.9 MB/s eta 0:00:00
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 88.6 MB/s eta 0:00:00
# Downloading lightecc-0.0.4-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: lz4, lightecc, gunicorn, fire, mtcnn, lightphe, lightdsa, flask-cors, retina-face, deepface
# Successfully installed deepface-0.0.99 fire-0.7.1 flask-cors-6.0.2 gunicorn-25.1.0 lightdsa-0.0.3 lightecc-0.0.4 lightphe-0.0.20 lz4-4.4.5 mtcnn-1.0.0 retina-face-0.0.17

# %%
# !pip uninstall -y deepface tensorflow keras
# !pip install -q deepface
# Out:
# Found existing installation: deepface 0.0.99
# Uninstalling deepface-0.0.99:
#   Successfully uninstalled deepface-0.0.99
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# Found existing installation: keras 3.10.0
# Uninstalling keras-3.10.0:
#   Successfully uninstalled keras-3.10.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 141.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 35.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpc-google-iam-v1 0.14.3 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-trace 1.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-monitoring 2.29.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-functions 1.22.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-speech 2.36.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-spanner 3.63.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# googleapis-common-protos 1.72.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-pubsub 2.35.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.21.0 which is incompatible.
# google-cloud-resource-manager 1.16.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-translate 3.24.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-firestore 2.23.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0dev,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-logging 3.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-language 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-iam 2.21.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-audit-log 0.4.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.21.0 which is incompatible.
# google-cloud-datastore 2.23.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-appengine-logging 1.8.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-secret-manager 2.26.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-dataproc 5.25.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# proto-plus 1.27.1 requires protobuf<7.0.0,>=3.19.0, but you have protobuf 7.34.0 which is incompatible.
# google-api-core 2.30.0 requires protobuf<7.0.0,>=4.25.8, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-bigtable 2.35.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-bigquery-storage 2.36.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-bigquery-connection 1.20.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-discoveryengine 0.13.12 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# google-cloud-aiplatform 1.139.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 7.34.0 which is incompatible.
# wandb 0.25.0 requires protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0; python_version > "3.9" and sys_platform == "linux", but you have protobuf 7.34.0 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.21.0 which is incompatible.

# %%
import tensorflow as tf
print(tf.__version__)

from deepface import DeepFace
print(DeepFace.__version__)
# Out:
# 2.21.0
# 26-03-07 10:33:46 - Directory /root/.deepface has been created
# 26-03-07 10:33:46 - Directory /root/.deepface/weights has been created
# 0.0.99

# %%
import os
import json
from tqdm import tqdm
from deepface import DeepFace
import numpy as np
import time
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
from tqdm import tqdm
from tqdm.contrib.concurrent import thread_map
tqdm.disable = True

from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import Counter

# ----------------- 辅助函数 -----------------
def age_to_class(age):
    """
    简单分类 age，返回字符串
    """
    if age == "unk" or age is None:
        return "unk"
    try:
        age = int(age)
        if age < 40:
            return "young"
        else:
            return "senior"
    except:
        return "unk"

def deepface_detection(json_path, image_folder, path_result, n_sample=10, start_index=0, save_interval=10):
    """
    批量处理房东头像，结合已有JSON信息，根据nb_face处理age/gender/smile
    json_path: str, 已有 JSON 文件路径
    image_folder: str, 图片文件夹路径
    n_sample: int, 处理前 n 张图片
    """

    # ----------------- 读取已有 JSON -----------------
    with open(json_path, "r", encoding="utf-8") as f:
        old_results = json.load(f)

    if start_index!=0:
        old_results=old_results[start_index:]
        print(f'[info] start at {start_index}e image!\n')
    if n_sample!=None:
        old_results = old_results[:n_sample]  # 可选择处理前 n_sample 张
        print(f'[info] process a sample of {n_sample} images!\n')

    results = []
    start_time=time.time()
    for i, item in enumerate(tqdm(old_results, desc="Processing images")):
        # ----------save interval-------------
        if (i+1) % save_interval==0:
            with open(path_result, 'w', encoding="utf-8")as f:
                json.dump(results, f, indent=2, ensure_ascii=False)
                print(f"\n[INTERNAL SAVE] {i+1} / {len(old_results)} results saved!\n")

        filename = os.path.basename(item["img_path"].replace("\\","/"))
        img_path = os.path.join(image_folder, filename)

        host_id = item["host_id"]
        has_face = item.get("has_face", 0)
        nb_face = item.get("nb_face", 0)
        bbox_list = item.get("bbox_list", [])

        # 默认输出结构
        row = {
            "img_path": img_path,
            "host_id": host_id,
            "has_face": has_face,
            "nb_face": nb_face,
            "face_area_ratio": item.get("face_area_ratio"),
            "avg_face_prob": item.get("avg_face_prob"),
            "bbox_list": item.get("bbox_list", []),
            "clean_score": item.get("clean_score"),
            "lifestyle_score": item.get("lifestyle_score"),
            "host_picture_type": item.get("host_picture_type"),
            "age": None,
            "age_class": "unk",
            "gender": None,
            "smile_score": 0,
            "is_smiling": 0,
            "dominant_emotion": None
        }

        # ----------------- nb_face 分支处理 -----------------
        if nb_face == 0:
            # 没有人脸
            row["age"] = "unk"
            row["gender"] = "unk"
            row["is_smiling"] = 0

        else: # 有至少一张脸
            # 至少一张脸
          try:
              analysis = DeepFace.analyze(
                  img_path=img_path,
                  actions=['age','gender','emotion'],
                  enforce_detection=False,
                  detector_backend="opencv",
              )

              # DeepFace 可能返回单个 dict 或列表
              if isinstance(analysis, dict):
                  analysis = [analysis]

              ages, smiles, emotions, genders = [], [], [], []

              for face_analysis in analysis:
                  ages.append(face_analysis.get("age", 0))
                  smiles.append(face_analysis.get("emotion", {}).get("happy", 0))
                  emotions.append(face_analysis.get("dominant_emotion", "neutral"))
                  genders.append(face_analysis.get("dominant_gender", "unk"))

              # 取平均年龄
              row["age"] = int(sum(ages)/len(ages))
              row["age_class"] = age_to_class(row["age"])

              # 平均微笑
              row["smile_score"] = float(sum(smiles)/len(smiles))
              row["is_smiling"] = 1 if row["smile_score"] > 40 else 0

              # 性别投票
              gender_counts = Counter(genders)
              if len(gender_counts) == 1:
                  row["gender"] = genders[0]
              else:
                  row["gender"] = "multi"

              # 主要情绪
              emotion_counts = Counter(emotions)
              row["dominant_emotion"] = emotion_counts.most_common(1)[0][0]

          except Exception as e:
              print(f"[ERROR] {e} for {img_path}")

        results.append(row)
    end_time=time.time()
    runtime=end_time-start_time
    print(f"[DONE] {len(results)} images detected : {runtime:.2f} sec!")
    print(f"[info] average runtime: {runtime/len(results):.2f} sec/img!")

    with open(path_result, 'w', encoding="utf-8")as f:
      json.dump(results, f, indent=2, ensure_ascii=False)
      print(f"\n[FINAL SAVE] {len(results)} / {len(old_results)} results saved!\n")

    return results

# %%
N_SAMPLE=20
IMAGE_FOLDER="/content/drive/MyDrive/airbnbMM2/host_pic/images/host_pic_paris_43258"
RESULT_FOLDER="/content/drive/MyDrive/airbnbMM2/host_pic/results"
PATH_RESULT=os.path.join(RESULT_FOLDER,f"deepface_results_paris{N_SAMPLE}.json")

# run
start_time=time.time()
results = deepface_detection(
    json_path=os.path.join(RESULT_FOLDER, "face_results_paris.json"),
    image_folder=IMAGE_FOLDER,
    path_result=PATH_RESULT,
    n_sample=N_SAMPLE,
    start_index=0,
    save_interval=10
)
# Out:
# [info] process a sample of 20 images!
# Processing images:   0%|          | 0/20 [00:00<?, ?it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:  33%|███▎      | 1/3 [00:02<00:04,  2.37s/it]
# Action: gender:  33%|███▎      | 1/3 [00:02<00:04,  2.37s/it]Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 26-03-06 19:17:02 - 🔗 gender_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5 to /root/.deepface/weights/gender_model_weights.h5...
#   0%|          | 0.00/537M [00:00<?, ?B/s]
#
#   4%|▍         | 21.5M/537M [00:00<00:02, 213MB/s]
#
#   9%|▊         | 46.7M/537M [00:00<00:02, 234MB/s]
#
#  13%|█▎        | 70.3M/537M [00:00<00:02, 227MB/s]
#
#  17%|█▋        | 93.3M/537M [00:00<00:02, 214MB/s]
#
#  22%|██▏       | 116M/537M [00:00<00:02, 207MB/s]
#
#  25%|██▌       | 137M/537M [00:00<00:03, 128MB/s]
#
#  29%|██▊       | 153M/537M [00:01<00:03, 96.2MB/s]
#
#  31%|███       | 166M/537M [00:01<00:08, 45.8MB/s]
#
#  33%|███▎      | 176M/537M [00:02<00:08, 42.3MB/s]
#
#  34%|███▍      | 183M/537M [00:02<00:08, 39.6MB/s]
#
#  35%|███▌      | 189M/537M [00:02<00:09, 36.0MB/s]
#
#  37%|███▋      | 200M/537M [00:02<00:09, 37.4MB/s]
#
#  39%|███▉      | 210M/537M [00:03<00:08, 38.4MB/s]
#
#  41%|████      | 221M/537M [00:03<00:08, 38.3MB/s]
#
#  43%|████▎     | 231M/537M [00:03<00:07, 39.1MB/s]
#
#  45%|████▍     | 242M/537M [00:03<00:07, 39.6MB/s]
#
#  47%|████▋     | 252M/537M [00:04<00:07, 39.3MB/s]
#
#  49%|████▉     | 263M/537M [00:04<00:06, 39.4MB/s]
#
#  51%|█████     | 273M/537M [00:04<00:06, 39.5MB/s]
#
#  53%|█████▎    | 284M/537M [00:05<00:06, 39.2MB/s]
#
#  55%|█████▍    | 294M/537M [00:05<00:06, 39.5MB/s]
#
#  57%|█████▋    | 305M/537M [00:05<00:05, 39.4MB/s]
#
#  59%|█████▊    | 315M/537M [00:06<00:08, 24.8MB/s]
#
#  61%|██████    | 326M/537M [00:07<00:10, 20.5MB/s]
#
#  63%|██████▎   | 336M/537M [00:07<00:08, 23.9MB/s]
#
#  65%|██████▍   | 347M/537M [00:07<00:07, 27.2MB/s]
#
#  66%|██████▋   | 357M/537M [00:07<00:05, 30.1MB/s]
#
#  68%|██████▊   | 368M/537M [00:08<00:05, 32.0MB/s]
#
#  70%|███████   | 378M/537M [00:08<00:04, 34.5MB/s]
#
#  72%|███████▏  | 388M/537M [00:08<00:04, 35.8MB/s]
#
#  74%|███████▍  | 399M/537M [00:08<00:03, 37.3MB/s]
#
#  76%|███████▌  | 409M/537M [00:09<00:03, 38.7MB/s]
#
#  78%|███████▊  | 420M/537M [00:09<00:03, 38.4MB/s]
#
#  80%|████████  | 430M/537M [00:09<00:02, 39.5MB/s]
#
#  82%|████████▏ | 441M/537M [00:09<00:02, 38.9MB/s]
#
#  84%|████████▍ | 451M/537M [00:10<00:02, 38.7MB/s]
#
#  86%|████████▌ | 462M/537M [00:10<00:01, 37.8MB/s]
#
#  88%|████████▊ | 472M/537M [00:10<00:01, 38.0MB/s]
#
#  90%|████████▉ | 483M/537M [00:11<00:01, 38.4MB/s]
#
#  92%|█████████▏| 493M/537M [00:11<00:01, 38.5MB/s]
#
#  94%|█████████▍| 504M/537M [00:11<00:00, 38.3MB/s]
#
#  96%|█████████▌| 514M/537M [00:11<00:00, 38.2MB/s]
#
#  98%|█████████▊| 525M/537M [00:12<00:00, 38.8MB/s]
#
# 100%|██████████| 537M/537M [00:12<00:00, 43.1MB/s]
#
# Action: gender:  67%|██████▋   | 2/3 [00:15<00:08,  8.94s/it]
# Action: emotion:  67%|██████▋   | 2/3 [00:15<00:08,  8.94s/it]
# 26-03-06 19:17:15 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to /root/.deepface/weights/facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 421MB/s]
#
# Action: emotion: 100%|██████████| 3/3 [00:16<00:00,  5.49s/it]
# Processing images:   5%|▌         | 1/20 [00:17<05:32, 17.52s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 46.41it/s]
# Processing images:  10%|█         | 2/20 [00:18<02:17,  7.63s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 44.32it/s]
# Processing images:  15%|█▌        | 3/20 [00:19<01:17,  4.53s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.13it/s]
# Processing images:  25%|██▌       | 5/20 [00:19<00:32,  2.19s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.38it/s]
# Processing images:  30%|███       | 6/20 [00:20<00:25,  1.85s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 46.87it/s]
# Processing images:  35%|███▌      | 7/20 [00:21<00:20,  1.58s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 45.89it/s]
# Processing images:  40%|████      | 8/20 [00:22<00:16,  1.39s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.38it/s]
# Processing images:  45%|████▌     | 9/20 [00:23<00:14,  1.32s/it]
# [INTERNAL SAVE] 10 / 20 results saved!
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.86it/s]
# Processing images:  50%|█████     | 10/20 [00:24<00:11,  1.14s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.22it/s]
# Processing images:  55%|█████▌    | 11/20 [00:25<00:10,  1.13s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 47.20it/s]
# Processing images:  60%|██████    | 12/20 [00:26<00:08,  1.04s/it]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 44.68it/s]
# Processing images:  65%|██████▌   | 13/20 [00:27<00:06,  1.07it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.34it/s]
# Processing images:  70%|███████   | 14/20 [00:28<00:05,  1.05it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 47.65it/s]
# Processing images:  75%|███████▌  | 15/20 [00:29<00:04,  1.06it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 48.19it/s]
# Processing images:  80%|████████  | 16/20 [00:30<00:03,  1.03it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 47.13it/s]
# Processing images:  85%|████████▌ | 17/20 [00:30<00:02,  1.12it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 45.60it/s]
#
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 45.86it/s]
# Processing images:  90%|█████████ | 18/20 [00:31<00:01,  1.12it/s]
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 47.03it/s]
# Processing images:  95%|█████████▌| 19/20 [00:32<00:00,  1.20it/s]
# [INTERNAL SAVE] 20 / 20 results saved!
# Finding actions:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: age:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: gender:   0%|          | 0/3 [00:00<?, ?it/s]
# Action: emotion: 100%|██████████| 3/3 [00:00<00:00, 47.19it/s]
# Processing images: 100%|██████████| 20/20 [00:33<00:00,  1.68s/it]
# [DONE] 20 images detected : 33.94 sec!
# [info] average runtime: 1.70 sec/img!
#
# [FINAL SAVE] 20 / 20 results saved!

# %% [markdown]
# ## APPLI BY BATCH

# %%
import os
import json
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
from tqdm.contrib.concurrent import thread_map
from collections import Counter
from deepface import DeepFace

# ----------------- 工具函数 -----------------
def age_to_class(age):
    if age == "unk" or age is None:
        return "unk"
    elif age < 30:
        return "young"
    elif age < 50:
        return "middle"
    else:
        return "senior"

# 单张图片处理函数
def process_one(item, image_folder):
    filename = os.path.basename(item["img_path"].replace("\\", "/"))
    img_path = os.path.join(image_folder, filename)

    row = {
        "img_path": img_path,
        "host_id": item["host_id"],
        "has_face": item.get("has_face", 0),
        "nb_face": item.get("nb_face", 0),
        "face_area_ratio": item.get("face_area_ratio"),
        "avg_face_prob": item.get("avg_face_prob"),
        "bbox_list": item.get("bbox_list", []),
        "clean_score": item.get("clean_score"),
        "lifestyle_score": item.get("lifestyle_score"),
        "host_picture_type": item.get("host_picture_type"),
        "age": None,
        "age_class": "unk",
        "gender": None,
        "smile_score": 0,
        "is_smiling": 0,
        "dominant_emotion": None
    }

    if row["nb_face"] == 0:
        # 没有人脸
        row["age"] = "unk"
        row["gender"] = "unk"
        row["is_smiling"] = 0
        return row

    # 至少一张脸
    try:
        analysis = DeepFace.analyze(
            img_path=img_path,
            actions=['age','gender','emotion'],
            enforce_detection=False,
            detector_backend="opencv",
        )

        # DeepFace 可能返回单个 dict 或列表
        if isinstance(analysis, dict):
            analysis = [analysis]

        ages, smiles, emotions, genders = [], [], [], []

        for face_analysis in analysis:
            ages.append(face_analysis.get("age", 0))
            smiles.append(face_analysis.get("emotion", {}).get("happy", 0))
            emotions.append(face_analysis.get("dominant_emotion", "neutral"))
            genders.append(face_analysis.get("dominant_gender", "unk"))

        # 取平均年龄
        row["age"] = int(sum(ages)/len(ages))
        row["age_class"] = age_to_class(row["age"])

        # 平均微笑
        row["smile_score"] = float(sum(smiles)/len(smiles))
        row["is_smiling"] = 1 if row["smile_score"] > 40 else 0

        # 性别投票
        gender_counts = Counter(genders)
        if len(gender_counts) == 1:
            row["gender"] = genders[0]
        else:
            row["gender"] = "multi"

        # 主要情绪
        emotion_counts = Counter(emotions)
        row["dominant_emotion"] = emotion_counts.most_common(1)[0][0]

    except Exception as e:
        print(f"[ERROR] {e} for {img_path}")

    return row

# ----------------- 主函数 -----------------
def deepface_detection_by_batch_with_json(
    json_path,
    image_folder,
    path_result,
    n_sample=None,
    max_workers=4,
    save_interval=50
):
    start_time = time.time()

    # 读取已有 JSON
    if os.path.exists(path_result):
        with open(path_result, "r", encoding="utf-8") as f:
            results = json.load(f)
        processed_ids = set([r["host_id"] for r in results])
        print(f"[INFO] {len(processed_ids)} images already processed, will skip them")
    else:
        results = []
        processed_ids = set()

    # 读取原始 JSON
    with open(json_path, "r", encoding="utf-8") as f:
        old_results = json.load(f)
    if n_sample:
        old_results = old_results[:n_sample]

    # 过滤已处理的图片
    pending = [item for item in old_results if item["host_id"] not in processed_ids]
    print(f"[INFO] {len(pending)} images to process")

    # -------- 多线程 + tqdm -----------
    processed_count = 0
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(process_one, item, image_folder): item for item in pending}
        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing images"):
            row = future.result()
            results.append(row)
            processed_count += 1

            # 定期保存
            if processed_count % save_interval == 0:
                with open(path_result, "w", encoding="utf-8") as f:
                    json.dump(results, f, indent=2, ensure_ascii=False)
                print(f"[INTERVAL SAVE] Saved {processed_count} / {len(pending)} images")

    # -------- 最终保存 --------
    with open(path_result, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
        print(f"[FINAL SAVE] Saved {processed_count} / {len(pending)} images")


    end_time = time.time()
    total_time = end_time - start_time
    avg_time = total_time / max(len(pending), 1)

    print(f"\n[DONE] {len(pending)} images processed in {total_time:.2f} sec")
    print(f"Average time per image: {avg_time:.2f} sec")

    return results

# %%
N_SAMPLE=None
IMAGE_FOLDER="/content/drive/MyDrive/airbnbMM2/host_pic/images/host_pic_paris_43258"
RESULT_FOLDER="/content/drive/MyDrive/airbnbMM2/host_pic/results"
PATH_RESULT=os.path.join(RESULT_FOLDER,f"deepface_results_paris.json")

results=deepface_detection_by_batch_with_json(
    json_path=os.path.join(RESULT_FOLDER, "face_results_paris.json"),
    image_folder=IMAGE_FOLDER,
    path_result=PATH_RESULT,
    n_sample=N_SAMPLE,
    max_workers=4,
    save_interval=1000
)
# Out:
# [INFO] 43055 images already processed, will skip them
# [INFO] 0 images to process
# Processing images: 0it [00:00, ?it/s]
# [FINAL SAVE] Saved 0 / 0 images
#
# [DONE] 0 images processed in 4.82 sec
# Average time per image: 4.82 sec

# %%
N_SAMPLE=None
IMAGE_FOLDER="/content/drive/MyDrive/airbnbMM2/host_pic/images/host_pic_london_25051"
RESULT_FOLDER="/content/drive/MyDrive/airbnbMM2/host_pic/results"
PATH_RESULT=os.path.join(RESULT_FOLDER,f"deepface_results_london.json")

results=deepface_detection_by_batch_with_json(
    json_path=os.path.join(RESULT_FOLDER, "face_results_london.json"),
    image_folder=IMAGE_FOLDER,
    path_result=PATH_RESULT,
    n_sample=N_SAMPLE,
    max_workers=4,
    save_interval=1000
)
# Out:
# [INFO] 24819 images already processed, will skip them
# [INFO] 0 images to process
# Processing images: 0it [00:00, ?it/s]
# [FINAL SAVE] Saved 0 / 0 images
#
# [DONE] 0 images processed in 2.32 sec
# Average time per image: 2.32 sec

# %% [markdown]
# ## VIS

# %%
import cv2
import random
import matplotlib.pyplot as plt

def visualize_face_results(results, n_samples=10, seed=42):
    """
    随机可视化若干检测结果
    """
    random.seed(seed)
    samples = random.sample(results, min(n_samples, len(results)))

    n_cols = 5
    n_rows = (len(samples) + n_cols - 1) // n_cols

    plt.figure(figsize=(4*n_cols, 4*n_rows))

    for i, item in enumerate(samples):
        img = cv2.imread(item["img_path"])
        if img is None:
            continue

        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # 画 bbox
        for bbox in item["bbox_list"]:
            x1, y1, x2, y2 = bbox
            cv2.rectangle(img_rgb, (x1,y1), (x2,y2), (255,0,0), 2)

        plt.subplot(n_rows, n_cols, i+1)
        plt.imshow(img_rgb)
        plt.axis("off")


        title = (
            f"{item['host_id']}\n"
            f"has_face={item['has_face']} | nb={item['nb_face']}\n"
            # f"area_ratio={round(item['face_area_ratio'],3)}\n"
            # f"avg_prob={round(item['avg_face_prob'],3)}\n"
            # f"clean_score={item['clean_score']:.2f} | lifestyle_scores={item['lifestyle_score']:.2f}\n"
            f"Type={item['host_picture_type']}\n"
            f"age={item['age']};age_class={item['age_class']}; gender={item['gender']}\n"
            f"smile_score={item['smile_score']:.2f}; similing={item['is_smiling']}\n"
            # f"emotion={item['dominant_emotion']}\n"
        )
        plt.title(title, fontsize=9)

    plt.tight_layout()
    plt.show()

    return

# %%
PATH_RESULT=os.path.join(RESULT_FOLDER, "deepface_results_london.json")
with open(PATH_RESULT, 'r', encoding='utf-8')as f:
    results=json.load(f)
    print(len(results))
visualize_face_results(results, n_samples=20, seed=42)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
